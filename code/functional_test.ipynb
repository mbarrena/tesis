# %%
import sys
sh_path = './scripts'
sys.path.insert(0, sh_path)

# %%
from tests import *
from regression import *
# %matplotlib inline
# Para elegir que modelo usar para regresión, descomentar la línea con el modelo
# que se quiera usar y comentar las otras dos. Despues correr la celda
REGRESS_MODEL = "VAR" #o "VECM" o "OLS"

# %%
df_trimestral_crudo = pd.read_excel("https://github.com/mbarrena/tesis/blob/main/data/Data%20trimestral%201950%20a%202023%20con%20DUMMIES%20outliers%20(por%20trimestre).xlsx?raw=true")
display(df_trimestral_crudo.head(140))
display(df_trimestral_crudo.tail())
# Out:
#       año trimestre     ipc_ajust         E           Ebc          pbird  \
# 0    1950      1ºTr  3.153126e-12       NaN  9.020000e-13  141630.000000
# 1    1950      2ºTr  3.385298e-12       NaN  9.020000e-13  139320.000000
# 2    1950      3ºTr  3.553683e-12       NaN  1.082330e-12  144669.000000
# 3    1950      4ºTr  3.806171e-12       NaN  1.403200e-12  142804.000000
# 4    1951      1ºTr  3.893961e-12       NaN  1.405173e-12  146731.000000
# ..    ...       ...           ...       ...           ...            ...
# 135  1983      4ºTr  3.013218e-05  0.000002  1.946000e-06  356406.312947
# 136  1984      1ºTr  4.732924e-05  0.000003  2.937333e-06  359573.567407
# 137  1984      2ºTr  7.834598e-05  0.000004  4.426900e-06  366827.229115
# 138  1984      3ºTr  1.367155e-04  0.000007  7.600833e-06  364304.377322
# 139  1984      4ºTr  2.374503e-04  0.000013  1.492180e-05  361366.266977
#
#       impp_usa  Psoja_USA  Pmaíz_USA  Ptrigo_USA  tot    TOTfmi  D1  D2
# 0          NaN   2.160000   1.166667    1.943333  NaN       NaN   0   0
# 1          NaN   2.663333   1.320000    2.060000  NaN       NaN   0   0
# 2          NaN   2.536667   1.440000    1.966667  NaN       NaN   0   0
# 3          NaN   2.423333   1.396667    1.953333  NaN       NaN   0   0
# 4          NaN   3.026667   1.580000    2.140000  NaN       NaN   0   0
# ..         ...        ...        ...         ...  ...       ...  ..  ..
# 135  60.935021   7.840000   3.156667    3.540000  NaN  96.39827   0   0
# 136  61.362723   7.603333   3.156667    3.463333  NaN  96.30234   0   0
# 137  62.029436   7.980000   3.340000    3.583333  NaN  96.38038   0   0
# 138  62.042016   6.513333   3.106667    3.383333  NaN  96.07735   0   0
# 139  61.828164   5.966667   2.586667    3.420000  NaN  95.92520   0   0
#
# [140 rows x 14 columns]
#       año trimestre     ipc_ajust           E         Ebc     pbird  \
# 291  2022      4ºTr  12057.901663  162.437267  167.092767  715542.0
# 292  2023      1ºTr  14379.348389  192.295133  197.672200  726438.0
# 293  2023      2ºTr  17925.305868  231.982867  239.525000  705636.0
# 294  2023      3ºTr  22933.827291  312.495167  325.102767  721285.0
# 295  2023      4ºTr  32893.178687  448.259000  506.338867  704495.0
#
#        impp_usa  Psoja_USA  Pmaíz_USA  Ptrigo_USA         tot      TOTfmi  D1  \
# 291  111.994742  13.966667   6.523333    9.100000  151.397002   99.653615   0
# 292  110.995728  14.833333   6.703333    8.566667  142.643274  100.255358   0
# 293  110.259612  14.500000   6.576667    8.016667  133.517789  100.212163   0
# 294  110.601380  14.000000   5.720000    7.336667  136.818441  100.063932   0
# 295  109.865265  12.933333   4.796667    6.756667  140.708694   99.721680   0
#
#      D2
# 291   0
# 292   0
# 293   0
# 294   0
# 295   0

# %%
df_Arg = df_trimestral_crudo[['año', 'trimestre', 'ipc_ajust', 'E', 'Ebc', 'pbird', 'impp_usa', 'Psoja_USA', 'Pmaíz_USA', 'Ptrigo_USA', 'TOTfmi', "D1", "D2"]].copy()
df_Arg = renameColumnOfDataframe(df_Arg, "ipc_ajust", "ipc")
display(df_Arg)
display(df_Arg.tail(20))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df_Arg = df_trimestral_crudo[['año', 'trimestre', 'ipc_ajust', 'E', 'Ebc', 'pbird', 'impp_usa', 'Psoja_USA', 'Pmaíz_USA', 'Ptrigo_USA', 'TOTfmi', "D1", "D2", "D3"]].copy()
#       2 df_Arg = renameColumnOfDataframe(df_Arg, "ipc_ajust", "ipc")
#       3 display(df_Arg)
#
# File ~/.pyenv/versions/3.12.5/envs/tesis_mariana/lib/python3.12/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.pyenv/versions/3.12.5/envs/tesis_mariana/lib/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/.pyenv/versions/3.12.5/envs/tesis_mariana/lib/python3.12/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['D3'] not in index"

# %%
df_Arg59 = df_Arg.copy().iloc[36:].reset_index(drop=True)[['año', 'trimestre', 'ipc', 'E', 'Ebc', 'pbird', 'impp_usa', 'Psoja_USA', 'Pmaíz_USA', 'Ptrigo_USA', 'TOTfmi', "D1", "D2"]].copy()
display(df_Arg59)
display(df_Arg59.tail)
# Out:
#       año trimestre           ipc             E           Ebc     pbird  \
# 0    1959      1ºTr  2.413144e-11  6.690000e-12  6.669333e-12  177276.0
# 1    1959      2ºTr  3.074744e-11  8.556667e-12  8.317000e-12  182783.0
# 2    1959      3ºTr  3.511185e-11  8.408333e-12  8.414333e-12  166259.0
# 3    1959      4ºTr  3.704045e-11  8.313333e-12  8.275667e-12  178163.0
# 4    1960      1ºTr  3.935256e-11  8.293333e-12  8.297333e-12  186316.0
# ..    ...       ...           ...           ...           ...       ...
# 255  2022      4ºTr  1.205790e+04  1.624373e+02  1.670928e+02  715542.0
# 256  2023      1ºTr  1.437935e+04  1.922951e+02  1.976722e+02  726438.0
# 257  2023      2ºTr  1.792531e+04  2.319829e+02  2.395250e+02  705636.0
# 258  2023      3ºTr  2.293383e+04  3.124952e+02  3.251028e+02  721285.0
# 259  2023      4ºTr  3.289318e+04  4.482590e+02  5.063389e+02  704495.0
#
#        impp_usa  Psoja_USA  Pmaíz_USA  Ptrigo_USA      TOTfmi  D1  D2  D3
# 0     13.237287   2.046667   1.043333    1.736667         NaN   0   0   0
# 1     13.251340   2.106667   1.150000    1.743333         NaN   0   0   0
# 2     13.279444   1.976667   1.116667    1.723333         NaN   0   0   0
# 3     13.476177   1.970000   0.985667    1.780000         NaN   0   0   0
# 4     13.504281   1.996667   1.009667    1.800000         NaN   0   0   0
# ..          ...        ...        ...         ...         ...  ..  ..  ..
# 255  111.994742  13.966667   6.523333    9.100000   99.653615   0   0   0
# 256  110.995728  14.833333   6.703333    8.566667  100.255358   0   0   0
# 257  110.259612  14.500000   6.576667    8.016667  100.212163   0   0   0
# 258  110.601380  14.000000   5.720000    7.336667  100.063932   0   0   0
# 259  109.865265  12.933333   4.796667    6.756667   99.721680   0   0   0
#
# [260 rows x 14 columns]
# <bound method NDFrame.tail of       año trimestre           ipc             E           Ebc     pbird  \
# 0    1959      1ºTr  2.413144e-11  6.690000e-12  6.669333e-12  177276.0
# 1    1959      2ºTr  3.074744e-11  8.556667e-12  8.317000e-12  182783.0
# 2    1959      3ºTr  3.511185e-11  8.408333e-12  8.414333e-12  166259.0
# 3    1959      4ºTr  3.704045e-11  8.313333e-12  8.275667e-12  178163.0
# 4    1960      1ºTr  3.935256e-11  8.293333e-12  8.297333e-12  186316.0
# ..    ...       ...           ...           ...           ...       ...
# 255  2022      4ºTr  1.205790e+04  1.624373e+02  1.670928e+02  715542.0
# 256  2023      1ºTr  1.437935e+04  1.922951e+02  1.976722e+02  726438.0
# 257  2023      2ºTr  1.792531e+04  2.319829e+02  2.395250e+02  705636.0
# 258  2023      3ºTr  2.293383e+04  3.124952e+02  3.251028e+02  721285.0
# 259  2023      4ºTr  3.289318e+04  4.482590e+02  5.063389e+02  704495.0
#
#        impp_usa  Psoja_USA  Pmaíz_USA  Ptrigo_USA      TOTfmi  D1  D2  D3
# 0     13.237287   2.046667   1.043333    1.736667         NaN   0   0   0
# 1     13.251340   2.106667   1.150000    1.743333         NaN   0   0   0
# 2     13.279444   1.976667   1.116667    1.723333         NaN   0   0   0
# 3     13.476177   1.970000   0.985667    1.780000         NaN   0   0   0
# 4     13.504281   1.996667   1.009667    1.800000         NaN   0   0   0
# ..          ...        ...        ...         ...         ...  ..  ..  ..
# 255  111.994742  13.966667   6.523333    9.100000   99.653615   0   0   0
# 256  110.995728  14.833333   6.703333    8.566667  100.255358   0   0   0
# 257  110.259612  14.500000   6.576667    8.016667  100.212163   0   0   0
# 258  110.601380  14.000000   5.720000    7.336667  100.063932   0   0   0
# 259  109.865265  12.933333   4.796667    6.756667   99.721680   0   0   0
#
# [260 rows x 14 columns]>

# %%
ChowTest(df_Arg59,19,21,y_vars=["ipc"],variables=removeInplace(df_Arg59.columns[2:-4],"tot"))
# Out:
# **Test de Chow:** idx before break 19, idx after break 21
# **ipc**:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ChowTest(df_Arg59,19,21,y_vars=["ipc"],variables=removeInplace(df_Arg59.columns[2:-4],"tot"))
#
# File /mnt/d/001.Maca/proyectos_hobbies/tesis-mariana/tesis/./scripts/tests.py:198, in ChowTest(datos, last_index, first_index, y_vars, variables)
#     196 for var in y_vars:
#     197   printmd(f"{bold(var)}:")
# --> 198   ct = chowtest.ChowTest(datos.drop(var, axis=1), datos[var],
#     199         last_index_in_model_1=last_index,
#     200         first_index_in_model_2=first_index)
#     201 print(f"ChowTest value: {ct[0]}, p_value: {ct[1]}")
#
# File /mnt/d/001.Maca/proyectos_hobbies/tesis-mariana/tesis/.venv/lib/python3.10/site-packages/chowtest/__init__.py:55, in ChowTest(X, y, last_index_in_model_1, first_index_in_model_2)
#      52 def ChowTest(X, y, last_index_in_model_1, first_index_in_model_2):
#      53
#      54     # gets the RSS for the entire period
# ---> 55     rss_pooled = calculate_RSS(X, y)
#      57     # splits the X and y dataframes and gets the rows from the first row in the dataframe
#      58     # to the last row in the model 1 testing period and then calculates the RSS
#      59     X1 = X.loc[:last_index_in_model_1]
#
# File /mnt/d/001.Maca/proyectos_hobbies/tesis-mariana/tesis/.venv/lib/python3.10/site-packages/chowtest/__init__.py:42, in calculate_RSS(X, y)
#      39 def calculate_RSS(X, y):
#      40
#      41     # calls the linear_residual function
# ---> 42     resid_data = linear_residuals(X, y)
#      43     # calculates the sum of squared resiudals
#      44     rss = resid_data.residuals_sq.sum()
#
# File /mnt/d/001.Maca/proyectos_hobbies/tesis-mariana/tesis/.venv/lib/python3.10/site-packages/chowtest/__init__.py:23, in linear_residuals(X, y)
#      21 # creates a dataframe with the predicted y in a column called y_hat
#      22 summary_result = pd.DataFrame(columns = ['y_hat'])
# ---> 23 yhat_list = [float(i[0]) for i in np.ndarray.tolist(model.predict(X))]
#      24 summary_result['y_hat'] = yhat_list
#      25 # saves the actual y values in the y_actual column
#
# File /mnt/d/001.Maca/proyectos_hobbies/tesis-mariana/tesis/.venv/lib/python3.10/site-packages/chowtest/__init__.py:23, in <listcomp>(.0)
#      21 # creates a dataframe with the predicted y in a column called y_hat
#      22 summary_result = pd.DataFrame(columns = ['y_hat'])
# ---> 23 yhat_list = [float(i[0]) for i in np.ndarray.tolist(model.predict(X))]
#      24 summary_result['y_hat'] = yhat_list
#      25 # saves the actual y values in the y_actual column
#
# TypeError: 'float' object is not subscriptable
