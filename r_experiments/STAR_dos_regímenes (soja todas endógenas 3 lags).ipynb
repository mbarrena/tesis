# 294 -0.0066540169 -0.0227282511 -0.0190768838 -0.066355995 -0.0004309435
# 295  0.0030948721 -0.0350913198 -0.1395592260 -0.088638101 -0.0014802719
# 296 -0.0066778211 -0.0792493717 -0.1760475732 -0.082354935 -0.0034261970

# %% [markdown]
# # Librerías

# %%
library(tsDyn)
library(vars)
library(dplyr)
library(ggplot2)
# Out:
# Loading required package: MASS
# Loading required package: strucchange
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# Loading required package: sandwich
#
# Loading required package: urca
#
# Loading required package: lmtest
#
#
# Attaching package: ‘dplyr’
#
#
# The following object is masked from ‘package:MASS’:
#
#     select
#
#
# The following object is masked from ‘package:gridExtra’:
#
#     combine
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# # Configuración general

# %%
############################################################
# CONFIGURACIÓN 3 lags (según Selected Orders de VAR)
############################################################

lag_var        <- 3        # número de rezagos
use_scaled_ipc <- FALSE    # NO CAMBIAR. TRUE = usar ipc estandarizada
use_soja_endog <- TRUE     # FALSE = tratar soja como exógena (por ahora solo quita del sistema)

nboot_test     <- 200
trim_value     <- 0.15
nthresh_value  <- 1        # 1 → dos regímenes
thDelay_value  <- 1
include_type   <- "const"

# %% [markdown]
# # Preparar dataset

# %%
############################################################
# 1. Preparar variables
############################################################

df <- df_ERPT_Arg

# Variable de transición
ipc_trans <- df$ipc
if(use_scaled_ipc){
  ipc_trans <- scale(ipc_trans)
}

# Endógenas
if(use_soja_endog){
  Y <- cbind(df$Psoja_USA, df$E, df$ipc, df$pbird)
  colnames(Y) <- c("Psoja_USA","E","ipc","pbird")
} else {
  Y <- cbind(df$E, df$ipc, df$pbird)
  colnames(Y) <- c("E","ipc","pbird")
}

# %% [markdown]
# # Test de linealidad (TVAR.LRtest)
# Esto devuelve: estadístico LR; p-value bootstrap; valores críticos. Si p-value < 0.05 hay evidencia de no linealidad.

# %%
############################################################
# 2. Test de linealidad
############################################################

test_lin <- TVAR.LRtest(
  data   = Y,
  lag    = lag_var,
  series = "ipc",
  thDelay= thDelay_value,
  thVar  = ipc_trans,
  trim   = trim_value,
  nboot  = nboot_test,
  test   = "1vs",
  model  = "TAR"
)

print(test_lin)
# Out:
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning message in FUN(newX[, i], ...):
# “Tolerance reached, ndp possibly underestimated.”
# Warning: the thDelay values do not correspond to the univariate implementation in tsdyn
# Test of linear VAR against TVAR(1) and TVAR(2)
#
# LR test:
#           1vs2     1vs3
# Test  191.5874 302.2569
# P-Val   0.0000   0.0000

# %% [markdown]
# # Estimación TVAR

# %%
############################################################
# 3. Estimar TVAR
############################################################

tvar_model <- TVAR(
  data     = Y,
  lag      = lag_var,
  include  = include_type,
  model    = "TAR",
  nthresh  = nthresh_value,
  thDelay  = thDelay_value,
  mTh      = if (use_soja_endog) 3 else 2,
  trim     = trim_value,
  trace    = TRUE
)

summary(tvar_model)
# Out:
# Best unique threshold 0.2405847
# Model TVAR with  1  thresholds
#
# Full sample size: 295 	End sample size: 292
# Number of variables: 4 	Number of estimated parameters: 104 + 1
# AIC -6009.155 	BIC -5623.096 	 SSR 13.62323
#
# [[1]]
#                    Intercept        Psoja_USA -1      E -1
# Equation Psoja_USA 0.0005(0.0099)   0.2463(0.0659)*** -0.0143(0.0641)
# Equation E         0.0201(0.0186)   -0.2223(0.1232).  0.4377(0.1198)***
# Equation ipc       0.0045(0.0099)   -0.0031(0.0659)   0.1409(0.0640)*
# Equation pbird     0.0090(0.0028)** 0.0394(0.0183)*   -0.0214(0.0178)
#                    ipc -1            pbird -1         Psoja_USA -2
# Equation Psoja_USA 0.4628(0.1748)**  0.1658(0.2333)   -0.3656(0.0667)***
# Equation E         0.1467(0.3270)    -0.7604(0.4364). 0.1645(0.1247)
# Equation ipc       0.6411(0.1748)*** 0.0755(0.2333)   0.0143(0.0667)
# Equation pbird     -0.0577(0.0487)   0.0778(0.0649)   -0.0189(0.0186)
#                    E -2             ipc -2           pbird -2
# Equation Psoja_USA -0.0627(0.0737)  -0.4472(0.1853)* -0.0378(0.2360)
# Equation E         -0.1657(0.1379)  0.7318(0.3467)*  -0.3499(0.4414)
# Equation ipc       -0.0345(0.0737)  0.1726(0.1853)   -0.0092(0.2360)
# Equation pbird     0.0068(0.0205)   -0.0421(0.0516)  0.0038(0.0657)
#                    Psoja_USA -3     E -3             ipc -3
# Equation Psoja_USA 0.0560(0.0690)   -0.0636(0.0653)  0.2077(0.1412)
# Equation E         -0.2193(0.1291). -0.0351(0.1221)  -0.2798(0.2641)
# Equation ipc       -0.0202(0.0690)  0.0028(0.0653)   0.0511(0.1412)
# Equation pbird     0.0491(0.0192)*  -0.0201(0.0182)  0.0803(0.0393)*
#                    pbird -3
# Equation Psoja_USA -0.1564(0.2335)
# Equation E         -0.0204(0.4368)
# Equation ipc       0.1815(0.2335)
# Equation pbird     -0.0862(0.0650)
#
# [[2]]
#                    Intercept         Psoja_USA -1     E -1
# Equation Psoja_USA 0.0175(0.0327)    0.4829(0.1895)*  0.0183(0.0752)
# Equation E         0.2777(0.0611)*** -0.2361(0.3544)  0.5694(0.1407)***
# Equation ipc       0.1926(0.0327)*** 0.1258(0.1895)   0.7849(0.0752)***
# Equation pbird     -0.0087(0.0091)   0.0242(0.0527)   -0.0128(0.0209)
#                    ipc -1             pbird -1         Psoja_USA -2
# Equation Psoja_USA -0.1664(0.1292)    0.2171(0.6376)   -0.0521(0.1437)
# Equation E         -0.2849(0.2417)    -0.4222(1.1926)  -0.7236(0.2687)**
# Equation ipc       -0.4484(0.1292)*** -0.0763(0.6375)  -0.5570(0.1437)***
# Equation pbird     -0.0108(0.0360)    -0.0290(0.1774)  0.1085(0.0400)**
#                    E -2               ipc -2            pbird -2
# Equation Psoja_USA 0.1366(0.0938)     -0.0524(0.1094)   0.7097(0.6676)
# Equation E         -0.3800(0.1755)*   0.6763(0.2047)**  3.1386(1.2487)*
# Equation ipc       -0.3400(0.0938)*** 0.7772(0.1094)*** 3.2697(0.6675)***
# Equation pbird     0.0607(0.0261)*    -0.0331(0.0305)   0.2226(0.1858)
#                    Psoja_USA -3     E -3             ipc -3
# Equation Psoja_USA -0.0660(0.1397)  -0.0824(0.0799)  0.1494(0.0970)
# Equation E         0.3144(0.2613)   -0.0357(0.1494)  -0.2604(0.1815)
# Equation ipc       0.0659(0.1397)   -0.0561(0.0799)  -0.1243(0.0970)
# Equation pbird     -0.0408(0.0389)  -0.0308(0.0222)  0.0516(0.0270).
#                    pbird -3
# Equation Psoja_USA 0.6228(0.7841)
# Equation E         -5.2972(1.4666)***
# Equation ipc       -4.4036(0.7840)***
# Equation pbird     0.3457(0.2182)
#
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Threshold value: 0.2405847
# Percentage of Observations in each regime: 84.6% 15.4%

# %%
table(regime(tvar_model))
# Out:
#   1   2
# 247  45

# %% [markdown]
# # GRÁFICOS

# %% [markdown]
# ## Configuración global: usando tvar_model
# 1. ERPT por régimen (IRF del TVAR)
# 2. ERPT rolling en el tiempo
# 3. Horizonte 4 y 8 trimestres

# %%
data_model <- df_ERPT_Arg[, c("Psoja_USA","E","ipc","pbird")]
data_model <- na.omit(data_model)

lag_var   <- lag_var
nthresh   <- nthresh_value
trim_val  <- trim_value
nboot_irf <- nboot_test

shock_var <- "E"
resp_var  <- "ipc"

h_short <- 4
h_long  <- 8

# %%
# Renombro test de linearidad para que coincida con el resto del codigo
lr_test <- test_lin

# %% [markdown]
# ## IRF por regimen ABSOLUTAS

# %%
irf_r1 <- vars::irf(
  tvar_model,
  impulse = shock_var,
  response = resp_var,
  regime = "L",
  n.ahead = h_long,
  boot = TRUE,
  runs = nboot_irf,
  ci = 0.68,
  cumulative = FALSE,
  ortho = FALSE
)

# %%
irf_r2 <- vars::irf(tvar_model, impulse=shock_var, response=resp_var,
              regime="H", n.ahead=h_long, boot=TRUE, runs=nboot_irf,
              ci = 0.68, cumulative = FALSE, ortho = FALSE)

# %% [markdown]
# ## ERPT por régimen

# %%
get_erpt <- function(irf_obj, h){
  cumsum(irf_obj$irf$E[,"ipc"])[h+1]
}

erpt_reg <- data.frame(
  regime = c("Baja","Alta"),
  ERPT_4 = c(get_erpt(irf_r1,4),
             get_erpt(irf_r2,4)),
  ERPT_8 = c(get_erpt(irf_r1,8),
             get_erpt(irf_r2,8))
)

print(erpt_reg)
# Out:
#   regime    ERPT_4    ERPT_8
# 1   Baja 0.4407495 0.7742001
# 2   Alta 0.7124239 0.4597547

# %% [markdown]
# ## Gráfico IRF ABSOLUTAS

# %%
extract_irf <- function(irf_obj, shock, response){

  irf_mat <- irf_obj$irf[[shock]]
  lo_mat  <- irf_obj$Lower[[shock]]
  hi_mat  <- irf_obj$Upper[[shock]]

  data.frame(
    h   = 0:(nrow(irf_mat)-1),
    irf = irf_mat[, response],
    lo  = lo_mat[, response],
    hi  = hi_mat[, response]
  )
}

df1 <- extract_irf(irf_r1, shock = shock_var, response = resp_var); df1$reg="Baja"
df2 <- extract_irf(irf_r2, shock = shock_var, response = resp_var); df2$reg="Alta"

df_all <- rbind(df1,df2)

ggplot(df_all, aes(h, irf, color=reg, fill=reg))+
  geom_line(linewidth=1.1)+
  geom_ribbon(aes(ymin=lo, ymax=hi), alpha=.15, color=NA)+
  theme_minimal(base_size = 14)+
  labs(title="Exchange Rate Pass-Through por régimen inflacionario",
       y="Respuesta IPC",
       x="Trimestres",
       color="Régimen",
       fill="Régimen")
# Out:
# plot without title

# %%
df_all
# Out:
#    h irf         lo          hi           reg
# 1  0  0.00000000  0.00000000  0.000000000 Baja
# 2  1  0.14085468  0.11919586  0.166183372 Baja
# 3  2  0.11586944  0.08232877  0.154464889 Baja
# 4  3  0.09467203  0.06258505  0.139279782 Baja
# 5  4  0.08935334  0.06037739  0.123395460 Baja
# 6  5  0.08926974  0.05993441  0.120739917 Baja
# 7  6  0.08363962  0.04731630  0.117548129 Baja
# 8  7  0.08163009  0.04531356  0.115894067 Baja
# 9  8  0.07891120  0.04096350  0.108630282 Baja
# 10 0  0.00000000  0.00000000  0.000000000 Alta
# 11 1  0.78487643  0.72615810  0.806791716 Alta
# 12 2 -0.24169884 -0.27251235 -0.166393450 Alta
# 13 3  0.19772532  0.09824204  0.257980921 Alta
# 14 4 -0.02847897 -0.07175679  0.091853206 Alta
# 15 5 -0.13357611 -0.19566555 -0.044613173 Alta
# 16 6  0.01808153 -0.03606203  0.111568918 Alta
# 17 7 -0.10113305 -0.14670496 -0.009828686 Alta
# 18 8 -0.03604160 -0.07873885  0.020280626 Alta

# %%
irf_r1$ortho
# Out:
# [1] FALSE

# %% [markdown]
# ## IRF por régimen ACUMULADAS

# %% [markdown]
# Acumulo manualmente las IRF absolutas (el paquete tsDyn no tiene IRF acumuladas)

# %%
extract_irf_cum <- function(irf_obj, shock, resp){

  # respuesta puntual
  irf_mat <- irf_obj$irf[[shock]][, resp]
  lo_mat  <- irf_obj$Lower[[shock]][, resp]
  hi_mat  <- irf_obj$Upper[[shock]][, resp]

  data.frame(
    h  = 0:(length(irf_mat)-1),
    irf = cumsum(irf_mat),
    lo  = cumsum(lo_mat),
    hi  = cumsum(hi_mat)
  )
}

# %%
df1 <- extract_irf_cum(irf_r1, shock_var, resp_var); df1$reg="Baja"
df2 <- extract_irf_cum(irf_r2, shock_var, resp_var); df2$reg="Alta"

df_all <- rbind(df1, df2)

# %%
df_all
# Out:
#    h irf       lo         hi        reg
# 1  0 0.0000000 0.00000000 0.0000000 Baja
# 2  1 0.1408547 0.11919586 0.1661834 Baja
# 3  2 0.2567241 0.20152463 0.3206483 Baja
# 4  3 0.3513961 0.26410968 0.4599280 Baja
# 5  4 0.4407495 0.32448708 0.5833235 Baja
# 6  5 0.5300192 0.38442149 0.7040634 Baja
# 7  6 0.6136589 0.43173779 0.8216115 Baja
# 8  7 0.6952889 0.47705135 0.9375056 Baja
# 9  8 0.7742001 0.51801486 1.0461359 Baja
# 10 0 0.0000000 0.00000000 0.0000000 Alta
# 11 1 0.7848764 0.72615810 0.8067917 Alta
# 12 2 0.5431776 0.45364575 0.6403983 Alta
# 13 3 0.7409029 0.55188779 0.8983792 Alta
# 14 4 0.7124239 0.48013100 0.9902324 Alta
# 15 5 0.5788478 0.28446544 0.9456192 Alta
# 16 6 0.5969294 0.24840342 1.0571881 Alta
# 17 7 0.4957963 0.10169846 1.0473595 Alta
# 18 8 0.4597547 0.02295961 1.0676401 Alta

# %% [markdown]
# ## Gráficos IRF ACUMULADAS

# %%
library(ggplot2)

ggplot(df_all, aes(h, irf, color=reg))+
  geom_line(linewidth=1)+
  geom_ribbon(aes(ymin=lo, ymax=hi, fill=reg),
              alpha=.15, color=NA)+
  theme_minimal()+
  labs(title="ERPT acumulado por régimen",
       y="Respuesta acumulada IPC",
       x="Trimestres")
# Out:
# plot without title
