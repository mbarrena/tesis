# %%
source("utils.r")
source("preparar_dataframes.r")
library(starvars)
library(zoo)
# Out:
# [1] "Se creó df_trimestral_crudo"
# [1] "Se creó df_Arg"
# [1] "Se creó df_ERPT_Arg1"
# [1] "Se creó df_ERPT_Arg"
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric

# %% [markdown]
# #### Pruebas realizadas
# | endog | iteraciones | convergence_method | n_combi | n_regimes | round_convergencia | coefs |
# | ----- | ----------- | ------------------ | ------- | --------- | ------------------ | ----- |
# | c("Psoja_USA", "E","ipc","pbird") | 150 | NLS | 2 | 2 | 95 | [] |
# | c("Psoja_USA", "E","ipc","pbird") | 150 | ML | 2 | 2 | 150 | [] |
# | c("Psoja_USA", "E","ipc","pbird") | 200 | ML | 2 | 3 | 200 | [] |
# | c("Psoja_USA", "E","ipc","pbird") | 300 | ML | 2 | 3 | 300 | [] |
# | c("Psoja_USA", "E","ipc","pbird") | 500 | ML | 2 | 3 | 500 | [] |

# %% [markdown]
# ## Configuración

# %%
df                  <- df_ERPT_Arg         # dataframe sobre el que trabajar
regression_var_lag  <- 2                   # lag order for endogenous variables (p)
transition_var_lag  <- 1                   # lag for the transition variable (used to select st)
trans_col           <- c('ipc')            # Variable de transición
n_regimes           <- 2                   # number of regimes (must be >= 2)
# NULL = use all numeric columns; or e.g. c("ipc","E","pbird")
endog_vars         <- c("Psoja_USA", "E","ipc","pbird")
exog_vars           <- c()                 # exogenous variable names (character vector, can be empty)
include_const       <- TRUE                # include intercept in the model
ncores              <- 4                   # number of cores for parallel computation
n_iter              <- 500                   # number of NLS iterations
n_combi             <- 5                   # number of gamma/c combinations tried in startingVLSTAR (subir a 3 para corridas finales)
convergence_method  <- 'ML'                # NLS (non-linear least squares) o ML (maximum likelihood)
single_cgamma       <- FALSE               # TRUE = one common gamma/c across equations
df
# Out:
#     año  trimestre ipc           E               Ebc             pbird
# 2   1950 2ºTr       0.0710476068  0.000000000000  0.000000000000 -0.016444578
# 3   1950 3ºTr       0.0485426448  0.182256883601  0.182256883601  0.037674929
# 4   1950 4ºTr       0.0686389229  0.259639217954  0.259639217954 -0.012975314
# 5   1951 1ºTr       0.0228032118  0.001405321461  0.001405321461  0.027127918
# 6   1951 2ºTr       0.1578569708  0.004855917800  0.004855917800  0.012084985
# 7   1951 3ºTr       0.1057701537  0.006299696673  0.006299696673 -0.006213927
# 8   1951 4ºTr       0.0767790005  0.013470343239  0.013470343239 -0.004386448
# 9   1952 1ºTr       0.1087066196 -0.016188205390 -0.016188205390  0.002419679
# 10  1952 2ºTr       0.0994670088 -0.011716739820 -0.011716739820 -0.032405660
# 11  1952 3ºTr      -0.0146396976 -0.002180054209 -0.002180054209 -0.051319867
# 12  1952 4ºTr       0.0335589046 -0.000011925930 -0.000011925930  0.008899268
# 13  1953 1ºTr       0.0266918756 -0.000004770412 -0.000004770412  0.026510169
# 14  1953 2ºTr      -0.0389677282  0.000000000000  0.000000000000  0.042126102
# 15  1953 3ºTr      -0.0005794234  0.000000000000  0.000000000000  0.023312842
# 16  1953 4ºTr      -0.0003745753  0.000000000000  0.000000000000  0.018833994
# 17  1954 1ºTr      -0.0115556363  0.000028622131  0.000028622131 -0.007995309
# 18  1954 2ºTr       0.0247062583 -0.000028622131 -0.000028622131 -0.038772971
# 19  1954 3ºTr       0.0445933755  0.000000000000  0.000000000000  0.057664962
# 20  1954 4ºTr       0.0682336937  0.000028622131  0.000028622131  0.046513832
# 21  1955 1ºTr       0.0111442897 -0.000028622131 -0.000028622131  0.012846801
# 22  1955 2ºTr       0.0185388828  0.000407788042  0.000407788042  0.004118190
# 23  1955 3ºTr       0.0133092121 -0.000193142028 -0.000193142028 -0.012313475
# 24  1955 4ºTr       0.0240193451  0.676481921608  0.676481921608  0.014790828
# 25  1956 1ºTr       0.0181833129  0.398873504896  0.398873504896  0.039285787
# 26  1956 2ºTr       0.0692667901 -0.106074933822 -0.106074933822 -0.001651480
# 27  1956 3ºTr       0.0309129577 -0.161338260421 -0.161338260421 -0.000888141
# 28  1956 4ºTr       0.0395146819  0.078676179220  0.078676179220 -0.062478307
# 29  1957 1ºTr       0.0392873804  0.119430275811  0.119430275811  0.086858914
# 30  1957 2ºTr       0.0839850354  0.051411006329  0.051411006329 -0.002193058
# 31  1957 3ºTr       0.0866657009  0.083471060749  0.083471060749  0.023946847
# ⋮   ⋮    ⋮         ⋮             ⋮               ⋮               ⋮
# 267 2016 3ºTr      0.05889485    0.048748847      0.045661933    -0.001563695
# 268 2016 4ºTr      0.04632878    0.031253323      0.036062584     0.011273309
# 269 2017 1ºTr      0.05058010    0.016435416     -0.002572173     0.011402752
# 270 2017 2ºTr      0.06201806    0.003871338      0.029898198     0.008703090
# 271 2017 3ºTr      0.04541372    0.094139213      0.083334605     0.006848522
# 272 2017 4ºTr      0.05171508    0.015473660      0.027815960     0.011203466
# 273 2018 1ºTr      0.06625591    0.122100607      0.107025857    -0.003458425
# 274 2018 2ºTr      0.07643576    0.169195705      0.217954416    -0.046775189
# 275 2018 3ºTr      0.10898373    0.309765527      0.346611714    -0.003404390
# 276 2018 4ºTr      0.13597250    0.145107373      0.061314316    -0.014282074
# 277 2019 1ºTr      0.09610715    0.052033639      0.063629731     0.002508715
# 278 2019 2ºTr      0.10540225    0.117297579      0.095333328     0.006530106
# 279 2019 3ºTr      0.09508683    0.139948070      0.200609224     0.001564971
# 280 2019 4ºTr      0.12321804    0.161505033      0.111782120    -0.017102984
# 281 2020 1ºTr      0.08464803    0.034971575      0.041064570    -0.046087696
# 282 2020 2ºTr      0.06090865    0.095927680      0.095870084    -0.149659994
# 283 2020 3ºTr      0.06626423    0.080278722      0.078642107     0.101566271
# 284 2020 4ºTr      0.09843793    0.087893896      0.090556758     0.048579131
# 285 2021 1ºTr      0.11547290    0.101143162      0.098888743     0.030067847
# 286 2021 2ºTr      0.11500866    0.060418203      0.053743077     0.006630028
# 287 2021 3ºTr      0.08909105    0.033150129      0.031901466     0.020718835
# 288 2021 4ºTr      0.09517261    0.032819167      0.034282746     0.023049216
# 289 2022 1ºTr      0.12446982    0.058993000      0.063956976     0.018898422
# 290 2022 2ºTr      0.16727386    0.101442857      0.109016261     0.013420036
# 291 2022 3ºTr      0.18763289    0.140983172      0.145683118    -0.002254719
# 292 2022 4ºTr      0.17199196    0.179883630      0.183463890    -0.022548941
# 293 2023 1ºTr      0.17607285    0.168739469      0.168060956     0.015112841
# 294 2023 2ºTr      0.22042041    0.187632174      0.192047692    -0.029053615
# 295 2023 3ºTr      0.24639954    0.297925484      0.305483542     0.021934820
# 296 2023 4ºTr      0.36065231    0.360782188      0.443064805    -0.023553109
#     impp_usa      Psoja_USA     Pmaíz_USA     Ptrigo_USA   TOTfmi
# 2             NA   0.209470249   0.123481057   0.058301271 NA
# 3             NA  -0.048727588   0.087011377  -0.046365921 NA
# 4             NA  -0.045706880  -0.030554668  -0.006802747 NA
# 5             NA   0.222317901   0.123336402   0.091268514 NA
# 6             NA   0.016384856   0.029108084  -0.014117882 NA
# 7             NA  -0.123214880   0.010193768  -0.025601398 NA
# 8             NA   0.007326040   0.000000000   0.053640618 NA
# 9             NA   0.012092046   0.010090903   0.010695289 NA
# 10            NA   0.022579688   0.025769513  -0.032435276 NA
# 11            NA   0.042559614   0.011673284  -0.041672696 NA
# 12            NA  -0.083332648  -0.143249642   0.033792435 NA
# 13            NA  -0.004907985  -0.024860037  -0.011137744 NA
# 14            NA   0.014652277   0.009111680  -0.037494204 NA
# 15            NA  -0.140307546   0.009029407  -0.063431714 NA
# 16            NA   0.086778900  -0.086807108   0.051735674 NA
# 17            NA   0.142759780   0.050189745   0.037927052 NA
# 18            NA   0.157628944   0.027587957  -0.034571344 NA
# 19            NA  -0.136783428   0.033447934   0.021541844 NA
# 20            NA  -0.181670303  -0.079859976   0.035430437 NA
# 21            NA   0.006489315  -0.011947573   0.011015060 NA
# 22            NA  -0.085014079   0.000000000  -0.017364288 NA
# 23            NA  -0.099120246  -0.054334351  -0.081237689 NA
# 24            NA  -0.028393075  -0.153305014   0.006884709 NA
# 25            NA   0.087278008   0.046251018   0.006837633 NA
# 26            NA   0.217850978   0.154150680   0.015215847 NA
# 27            NA  -0.210546344   0.042660497  -0.030666798 NA
# 28            NA  -0.038580452  -0.174463878   0.053885088 NA
# 29            NA   0.031275818   0.000000000   0.021087562 NA
# 30  -0.005708864  -0.025242617   0.010989122  -0.047667199 NA
# 31  -0.005741643  -0.001504891  -0.013755375  -0.039490110 NA
# ⋮   ⋮             ⋮             ⋮             ⋮            ⋮
# 267  0.0077670293  0.0194844653 -0.0977543941 -0.183695498 -0.0027628013
# 268  0.0055111740 -0.0390040812 -0.0181091468  0.049182911 -0.0020720421
# 269  0.0098442140  0.0294801997  0.0475808279  0.090060824  0.0008562263
# 270  0.0010878435 -0.0540672213 -0.0019379851  0.003184716 -0.0008227316
# 271  0.0029854819  0.0104074150 -0.0275336961  0.125350164 -0.0001855927
# 272  0.0158626797 -0.0111291761 -0.0396594934 -0.028451421 -0.0017355752
# 273  0.0129854746  0.0323238939  0.0545039025  0.056797598  0.0019801078
# 274  0.0096948224  0.0217813278  0.0628179849  0.077995624  0.0008203718
# 275 -0.0002607902 -0.1002814766 -0.0579184160 -0.025544173 -0.0067579271
# 276 -0.0118065126 -0.0361856262  0.0135924423  0.017313674 -0.0006382193
# 277 -0.0047619138  0.0066419467  0.0378474689  0.004440223  0.0025904251
# 278  0.0060806532 -0.0425596144  0.0337777433 -0.084482931  0.0009019383
# 279 -0.0103325863  0.0137209578  0.0651554762 -0.101389226  0.0006977979
# 280 -0.0034680574  0.0369829716 -0.0562188662  0.027069322  0.0009244699
# 281 -0.0091275801  0.0007722008  0.0008892842  0.081183349  0.0030131408
# 282 -0.0356886626 -0.0369538903 -0.1534102133 -0.030557933  0.0016145099
# 283  0.0300091342  0.0556889059  0.0092832023 -0.026439554 -0.0004307148
# 284  0.0070270559  0.1453457966  0.1547371901  0.126993048  0.0040498330
# 285  0.0346733159  0.1867880384  0.1994706473  0.090777660  0.0044533354
# 286  0.0350195529  0.1603426501  0.2156225439  0.086962842  0.0009775207
# 287  0.0142164759 -0.0769610411  0.0392877171  0.121513389 -0.0085806556
# 288  0.0205889626 -0.0915671935 -0.1285188508  0.168435200 -0.0052076295
# 289  0.0411130730  0.1638878551  0.1462282234  0.096653120  0.0066660790
# 290  0.0336531700  0.1162314450  0.1747043952  0.107860109  0.0005969103
# 291 -0.0229999892 -0.0707690709 -0.0060060241 -0.165722861 -0.0066010524
# 292 -0.0188355760 -0.0713766628 -0.0977691784  0.048021229  0.0031935266
# 293 -0.0089602109  0.0602033622  0.0272194224 -0.060395710  0.0060201888
# 294 -0.0066540169 -0.0227282511 -0.0190768838 -0.066355995 -0.0004309435
# 295  0.0030948721 -0.0350913198 -0.1395592260 -0.088638101 -0.0014802719
# 296 -0.0066778211 -0.0792493717 -0.1760475732 -0.082354935 -0.0034261970

# %% [markdown]
# ## Setup datos

# %%
raw <- df

# Keep only numeric columns (drop año, trimestre, etc.)
numeric_cols <- names(raw)[sapply(raw, is.numeric)]
numeric_cols <- numeric_cols[numeric_cols != "año"]
 
# Select endogenous variables
if (is.null(endog_vars)) {
  endog_vars <- numeric_cols
} else {
  endog_vars <- intersect(endog_vars, numeric_cols)
}
 
# Build the main numeric matrix (rows = observations)
df_num <- raw[, endog_vars, drop = FALSE]
 
# Drop rows where ALL endogenous variables are NA
keep      <- rowSums(is.na(df_num)) < ncol(df_num)
df_num    <- df_num[keep, ]
raw_clean <- raw[keep, ]          # keep raw in sync for date reconstruction
 
# For columns with isolated NAs, replace with column mean (simple imputation)
for (col in names(df_num)) {
  if (any(is.na(df_num[[col]]))) {
    col_mean <- mean(df_num[[col]], na.rm = TRUE)
    df_num[[col]][is.na(df_num[[col]])] <- col_mean
    message("Note: NA values in '", col, "' replaced with column mean.\nTODO: VER SI ESTO ES UN COMPORTAMIENTO ACEPTABLE O METE RUIDO!!")
  }
}

# %% [markdown]
# ### Build date index

# %%
# Detect the year column (handles "anno", "año", "year", etc.)
year_col <- names(raw_clean)[grep("^a", names(raw_clean), ignore.case = TRUE)[1]]
tq_col   <- names(raw_clean)[grep("trimestre", names(raw_clean), ignore.case = TRUE)[1]]
 
# Map quarter number to first month of each quarter
q2m <- c("1" = "01", "2" = "04", "3" = "07", "4" = "10")
 
# Extract the leading digit from strings like "1oTr", "2oTr", "1ºTr", etc.
tq_number    <- substr(as.character(raw_clean[[tq_col]]), 1, 1)
months       <- q2m[tq_number]
date_strings <- paste0(raw_clean[[year_col]], "-", months, "-01")
all_dates    <- as.Date(date_strings)             # length == T_full

# %% [markdown]
# ```txt
#  =============================================================================
#  2. BUILD y AND st FOLLOWING THE starvars CONVENTION
#
#     The package example does:
#       y  <- Realized[-1, 1:10]          # drop first row, use as levels
#       y  <- y[-nrow(y), ]               # drop last row
#       st <- Realized[-nrow(Realized), 1]# drop last row of full series
#       st <- st[-length(st)]             # drop last element
#
#     In plain terms:
#       - y  contains rows [2, T-1]  of the data matrix
#       - st contains rows [1, T-2]  of the chosen transition variable
#     This means st_t is dated one step before y_t (i.e., st uses lag = 1).
#     Increase the initial offset to use a longer lag for the transition variable.
#  =============================================================================
#  ```

# %%
T_full <- nrow(df_num)
 
# Validate transition variable column
if (!trans_col %in% names(df_num)) {
  stop("trans_col '", trans_col, "' not found in the data. ",
       "Available columns: ", paste(names(df_num), collapse = ", "))
}
 
offset <- transition_var_lag
 
# y: rows (offset+1) through (T_full - 1)
y <- as.matrix(df_num[(offset + 1):(T_full - 1), , drop = FALSE])
rownames(y) <- NULL
 
# st: plain numeric values, rows 1 through (T_full - 1 - offset)
st_values <- df_num[[trans_col]][1:(T_full - 1 - offset)]
st_dates  <- all_dates[1:(T_full - 1 - offset)]
 
# Wrap in zoo so plot.VLSTAR can extract a Date index via index()
st <- zoo(st_values, order.by = format(st_dates, "%m/%d/%Y"))

# %%
# Cap los valores extremos de la variable de transición a un percentil razonable,
# sin alterar el resto de la distribución
cap <- quantile(st_values, 0.95, na.rm = TRUE)
st_values_capped <- pmin(st_values, cap)
st <- zoo(st_values_capped, order.by = st_dates)

# %%
cat("==============================================================\n")
cat("Dataset summary\n")
cat("  Full observations      :", T_full, "\n")
cat("  Endogenous variables   :", ncol(y), "->", paste(endog_vars, collapse = ", "), "\n")
cat("  y dimensions           :", nrow(y), "rows x", ncol(y), "cols\n")
cat("  st length              :", length(st), "\n")
cat("  Regression lag (p)     :", regression_var_lag, "\n")
cat("  Transition variable    :", trans_col, "\n")
cat("  Transition var lag     :", transition_var_lag, "\n")
cat("  Number of regimes      :", n_regimes, "\n")
cat("  Include constant       :", include_const, "\n")
cat("==============================================================\n\n")
# Out:
# ==============================================================
# Dataset summary
#   Full observations      : 295
#   Endogenous variables   : 4 -> Psoja_USA, E, ipc, pbird
#   y dimensions           : 293 rows x 4 cols
#   st length              : 293
#   Regression lag (p)     : 2
#   Transition variable    : ipc
#   Transition var lag     : 1
#   Number of regimes      : 2
#   Include constant       : TRUE
# ==============================================================

# %%
st_plot <- zoo(as.numeric(st), order.by = st_dates)

plot(st_plot, type = "l", col = "steelblue", lwd = 1.5,
     main = paste("Variable de transición:", trans_col),
     xlab = "Fecha", ylab = trans_col)
abline(h = mean(st_plot), col = "grey50", lty = 2)
abline(h = quantile(st_plot, c(0.01, 0.99)), col = "red", lty = 3)

cat("Resumen de st:\n")
print(summary(as.numeric(st_plot)))
cat("Observaciones con |st| > 1 (posibles outliers extremos):\n")
print(st_plot[abs(as.numeric(st_plot)) > 1])
# Out:
# Resumen de st:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -0.03897  0.02483  0.06055  0.10729  0.13492  0.44433
# Observaciones con |st| > 1 (posibles outliers extremos):
# Data:
# numeric(0)
#
# Index:
# Date of length 0
# Plot with title “Variable de transición: ipc”

# %% [markdown]
# ## Modelar

# %% [markdown]
# ### Probar linearidad

# %% [markdown]
# ```txt
# # =============================================================================
# # 3b. LINEARITY TEST (run this before estimating -- if linearity is not
# #     rejected the VLSTAR is unidentified and coefficients will be empty)
# #
# #     VLSTARjoint() tests H0: gamma = 0 for all equations (i.e. the model
# #     is linear).  You need to reject H0 to justify estimating a VLSTAR.
# # =============================================================================
# ```

# %%
cat(">>> Testing linearity via VLSTARjoint ...\n")
linearity_test <- VLSTARjoint(y, st = st)
print(linearity_test)
 
cat("\n")
cat("If p-value >> 0.05: linearity NOT rejected -> VLSTAR may not be appropriate.\n")
cat("If p-value <  0.05: nonlinearity detected  -> proceed with VLSTAR.\n\n")
# Out:
# >>> Testing linearity via VLSTARjoint ...
#
# Joint linearity test (Third-order Taylor expansion)
#  LM = 188 ; p-value = 0.000000000000000000000000000000749
#  Critical value for alpha = 30.2
#
# If p-value >> 0.05: linearity NOT rejected -> VLSTAR may not be appropriate.
# If p-value <  0.05: nonlinearity detected  -> proceed with VLSTAR.

# %% [markdown]
# ### Generar valores iniciales

# %%
stvalues <- startingVLSTAR(
  y,
  p            = regression_var_lag,
  n.combi      = n_combi,
  singlecgamma = single_cgamma,
  st           = st,
  ncores       = ncores,
  m = n_regimes
)
# Out:
# Searching optimal c and gamma among 25 combinations
#   |======================================================================| 100%

# %% [markdown]
# ### Estimatar VLstar

# %%
#fit.VLSTAR <- readRDS("fit_vlstar.rds")

# %%
sink("output.txt", split = TRUE)
fit.VLSTAR <- VLSTAR(
  y,
  p            = regression_var_lag,
  singlecgamma = single_cgamma,
  starting     = stvalues,
  n.iter       = n_iter,
  st           = st,
  method       = convergence_method,
  ncores       = ncores,
  m = n_regimes
)
sink()
# Out:
# Maximum likelihood estimation
#
#
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 1 complete
# Log-likelihood: 4871.844
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 2 complete
# Log-likelihood: -1059.985
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 3 complete
# Log-likelihood: 3756.309
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 4 complete
# Log-likelihood: -1059.986
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 5 complete
# Log-likelihood: 3757.015
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 6 complete
# Log-likelihood: -1059.986
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 7 complete
# Log-likelihood: 3757.009
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 8 complete
# Log-likelihood: -1059.986
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 9 complete
# Log-likelihood: 3757.009
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 10 complete
# Log-likelihood: -1059.986
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 11 complete
# Log-likelihood: 3757.009
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 12 complete
# Log-likelihood: -1059.986
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 13 complete
# Log-likelihood: 3757.009
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 14 complete
# Log-likelihood: -1059.986
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 15 complete
# Log-likelihood: 3757.009
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# ...
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 494 complete
# Log-likelihood: -1059.986
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 495 complete
# Log-likelihood: 3757.009
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 496 complete
# Log-likelihood: -1059.986
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 497 complete
# Log-likelihood: 3757.009
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 498 complete
# Log-likelihood: -1059.986
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 499 complete
# Log-likelihood: 3757.009
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in par < lower:
# “longer object length is not a multiple of shorter object length”
# Warning message in matrix(rep(param1$par, ncoly), ncol = 2L, nrow = (ncoly * (m - :
# “data length differs from size of matrix: [32 != 4 x 2]”
# iteration 500 complete
# Log-likelihood: -1059.986
# Converged after 500 iterations

# %%
# Save the fitted model so you can reload it without re-running
saveRDS(fit.VLSTAR, "fit_vlstar_claude.rds")
cat(">>> Fit saved to fit_vlstar_claude.rds\n")
# Out:
# >>> Fit saved to fit_vlstar_claude.rds

# %% [markdown]
# ## Resultados - no acumulado

# %%
system("spd-say 'Model estimation complete'")
# Out:
# Warning message in system("spd-say 'Model estimation complete'"):
# “error in running command”

# %%
iterations <- as.numeric(gsub(".*after ([0-9]+) iterations.*", "\\1", grep("Converged after", readLines("output.txt"), value = TRUE)))
cat(">>> ITERATIONS\n")
cat(iterations)
cat("\n>>> Coefficients\n")
coefs <- coef(fit.VLSTAR)
summary(fit.VLSTAR)
# Out:
# >>> ITERATIONS
#
# >>> Coefficients
# Model VLSTAR with 2 regimes
# Full sample size: 291
# Number of estimated parameters: 88 	Multivariate log-likelihood: -1059.986
#
# Unique gamma: 20 	Unique c: 0.4443
# ==================================================
#
# Equation y1
#
# Coefficients regime 1
#           const Psoja_USA.lag-1         E.lag-1       ipc.lag-1     pbird.lag-1
#       -2.6e-07        -1.1e-09        -4.5e-08        -4.7e-08        -9.0e-10
# Psoja_USA.lag-2         E.lag-2       ipc.lag-2     pbird.lag-2
#       -8.9e-10        -4.5e-08        -4.5e-08        -9.3e-10
#
# Coefficients regime 2
#           const Psoja_USA.lag-1         E.lag-1       ipc.lag-1     pbird.lag-1
#       -2.7e-07        -9.8e-10        -5.8e-08        -6.0e-08        -6.2e-10
# Psoja_USA.lag-2         E.lag-2       ipc.lag-2     pbird.lag-2
#       -6.1e-10        -5.7e-08        -5.5e-08        -7.8e-10
# AIC: -997.75 	BIC: -931.63 	LL: 516.87
#
# Equation y2
#
# Coefficients regime 1
#           const Psoja_USA.lag-1         E.lag-1       ipc.lag-1     pbird.lag-1
#       -5.8e-07        -2.4e-09        -1.0e-07        -1.1e-07        -2.0e-09
# Psoja_USA.lag-2         E.lag-2       ipc.lag-2     pbird.lag-2
#       -2.0e-09        -1.0e-07        -1.0e-07        -2.1e-09
#
# Coefficients regime 2
#           const Psoja_USA.lag-1         E.lag-1       ipc.lag-1     pbird.lag-1
#       -6.2e-07        -2.2e-09        -1.3e-07        -1.3e-07        -1.4e-09
# Psoja_USA.lag-2         E.lag-2       ipc.lag-2     pbird.lag-2
#       -1.4e-09        -1.3e-07        -1.2e-07        -1.8e-09
# AIC: -445.2 	BIC: -379.09 	LL: 240.6
#
# Equation y3
#
# Coefficients regime 1
#           const Psoja_USA.lag-1         E.lag-1       ipc.lag-1     pbird.lag-1
#        6.9e-07         2.9e-09         1.2e-07         1.3e-07         2.4e-09
# Psoja_USA.lag-2         E.lag-2       ipc.lag-2     pbird.lag-2
#        2.4e-09         1.2e-07         1.2e-07         2.5e-09
#
# Coefficients regime 2
#           const Psoja_USA.lag-1         E.lag-1       ipc.lag-1     pbird.lag-1
#        7.4e-07         2.6e-09         1.6e-07         1.6e-07         1.7e-09
# Psoja_USA.lag-2         E.lag-2       ipc.lag-2     pbird.lag-2
#        1.6e-09         1.5e-07         1.5e-07         2.1e-09
# AIC: -515.96 	BIC: -449.84 	LL: 275.98
#
# Equation y4
#
# Coefficients regime 1
#           const Psoja_USA.lag-1         E.lag-1       ipc.lag-1     pbird.lag-1
#       -4.4e-09        -1.8e-11        -7.6e-10        -8.0e-10        -1.5e-11
# Psoja_USA.lag-2         E.lag-2       ipc.lag-2     pbird.lag-2
#       -1.5e-11        -7.7e-10        -7.6e-10        -1.6e-11
#
# Coefficients regime 2
#           const Psoja_USA.lag-1         E.lag-1       ipc.lag-1     pbird.lag-1
#       -4.7e-09        -1.7e-11        -9.8e-10        -1.0e-09        -1.1e-11
# Psoja_USA.lag-2         E.lag-2       ipc.lag-2     pbird.lag-2
#       -1.0e-11        -9.7e-10        -9.4e-10        -1.3e-11
# AIC: -1748.3 	BIC: -1682.18 	LL: 892.15
# ==================================================
#
#  Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
cat("\n>>> print(fit.VLSTAR)\n")
print(fit.VLSTAR)
 
cat("\n>>> summary(fit.VLSTAR)\n")
summary(fit.VLSTAR)
 
cat("\n>>> predict (1-step ahead)\n")
pred <- predict(fit.VLSTAR, st.num = 1, n.ahead = 1)
print(pred)
 
cat("\n>>> Log-likelihood (univariate)\n")
ll <- logLik(fit.VLSTAR, type = "Univariate")
print(ll)
 
cat("\n>>> Coefficients\n")
coefs <- coef(fit.VLSTAR)
print(coefs)

cat("\n>>> plot(fit.VLSTAR)\n")
plot(fit.VLSTAR)
# Out:
# >>> print(fit.VLSTAR)
#
# VLSTAR model Estimation through ML
# Coefficients:
# $`Regime 1`
# [1] Psoja_USA E         ipc       pbird
# <0 rows> (or 0-length row.names)
#
# $`Regime 2`
# [1] Psoja_USA E         ipc       pbird
# <0 rows> (or 0-length row.names)
#
#
# Smoothing parameter: gamma = 20 20 20 20
#
# Threshold
# Value: 0.4443 0.4443 0.4443 0.4443
#
# >>> summary(fit.VLSTAR)
# Model VLSTAR with 2 regimes
# Full sample size: 291
# Number of estimated parameters: 88 	Multivariate log-likelihood: -1059.986
#
# Unique gamma: 20 	Unique c: 0.4443
# ==================================================
#
# Equation y1
#
# Coefficients regime 1
#           const Psoja_USA.lag-1         E.lag-1       ipc.lag-1     pbird.lag-1
#       -2.6e-07        -1.1e-09        -4.5e-08        -4.7e-08        -9.0e-10
# Psoja_USA.lag-2         E.lag-2       ipc.lag-2     pbird.lag-2
#       -8.9e-10        -4.5e-08        -4.5e-08        -9.3e-10
#
# Coefficients regime 2
#           const Psoja_USA.lag-1         E.lag-1       ipc.lag-1     pbird.lag-1
#       -2.7e-07        -9.8e-10        -5.8e-08        -6.0e-08        -6.2e-10
# Psoja_USA.lag-2         E.lag-2       ipc.lag-2     pbird.lag-2
#       -6.1e-10        -5.7e-08        -5.5e-08        -7.8e-10
# AIC: -997.75 	BIC: -931.63 	LL: 516.87
#
# Equation y2
#
# Coefficients regime 1
#           const Psoja_USA.lag-1         E.lag-1       ipc.lag-1     pbird.lag-1
#       -5.8e-07        -2.4e-09        -1.0e-07        -1.1e-07        -2.0e-09
# Psoja_USA.lag-2         E.lag-2       ipc.lag-2     pbird.lag-2
#       -2.0e-09        -1.0e-07        -1.0e-07        -2.1e-09
#
# Coefficients regime 2
#           const Psoja_USA.lag-1         E.lag-1       ipc.lag-1     pbird.lag-1
#       -6.2e-07        -2.2e-09        -1.3e-07        -1.3e-07        -1.4e-09
# Psoja_USA.lag-2         E.lag-2       ipc.lag-2     pbird.lag-2
#       -1.4e-09        -1.3e-07        -1.2e-07        -1.8e-09
# AIC: -445.2 	BIC: -379.09 	LL: 240.6
#
# Equation y3
#
# Coefficients regime 1
#           const Psoja_USA.lag-1         E.lag-1       ipc.lag-1     pbird.lag-1
#        6.9e-07         2.9e-09         1.2e-07         1.3e-07         2.4e-09
# Psoja_USA.lag-2         E.lag-2       ipc.lag-2     pbird.lag-2
#        2.4e-09         1.2e-07         1.2e-07         2.5e-09
#
# Coefficients regime 2
#           const Psoja_USA.lag-1         E.lag-1       ipc.lag-1     pbird.lag-1
#        7.4e-07         2.6e-09         1.6e-07         1.6e-07         1.7e-09
# Psoja_USA.lag-2         E.lag-2       ipc.lag-2     pbird.lag-2
#        1.6e-09         1.5e-07         1.5e-07         2.1e-09
# AIC: -515.96 	BIC: -449.84 	LL: 275.98
#
# Equation y4
#
# Coefficients regime 1
#           const Psoja_USA.lag-1         E.lag-1       ipc.lag-1     pbird.lag-1
#       -4.4e-09        -1.8e-11        -7.6e-10        -8.0e-10        -1.5e-11
# Psoja_USA.lag-2         E.lag-2       ipc.lag-2     pbird.lag-2
#       -1.5e-11        -7.7e-10        -7.6e-10        -1.6e-11
#
# Coefficients regime 2
#           const Psoja_USA.lag-1         E.lag-1       ipc.lag-1     pbird.lag-1
#       -4.7e-09        -1.7e-11        -9.8e-10        -1.0e-09        -1.1e-11
# Psoja_USA.lag-2         E.lag-2       ipc.lag-2     pbird.lag-2
#       -1.0e-11        -9.7e-10        -9.4e-10        -1.3e-11
# AIC: -1748.3 	BIC: -1682.18 	LL: 892.15
# ==================================================
#
#  Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# >>> predict (1-step ahead)
# $Psoja_USA
#                  fcst   lower 95%  upper 95%
# [1,] -0.0000002946404 -0.01029208 0.01029149
#
# $E
#                  fcst   lower 95%  upper 95%
# [1,] -0.0000006638572 -0.02659591 0.02659458
#
# $ipc
#                fcst   lower 95%  upper 95%
# [1,] 0.000000793475 -0.02355006 0.02355164
#
# $pbird
#                    fcst    lower 95%   upper 95%
# [1,] -0.000000005012671 -0.002834164 0.002834154
#
#
# >>> Log-likelihood (univariate)
# 'log Lik.' 516.8738, 240.6025, 275.9796, 892.1478 (df=564)
#
# >>> Coefficients
# NULL
#
# >>> plot(fit.VLSTAR)
# Plot with title “Logistic function for Psoja_USA”
# Plot with title “Logistic function for E”
# Plot with title “Logistic function for ipc”
# Plot with title “Logistic function for pbird”

# %% [markdown]
# ## Resultados - acumulado

# %% [markdown]
# ```txt
# #    irf.VLSTAR() computes regime-specific IRFs for the VLSTAR model.
# #    We then cumulate them across horizons to get the total accumulated
# #    effect of a shock — particularly useful for ERPT analysis, e.g.
# #    "what is the total pass-through from E to ipc over N quarters?"
# #
# #    Arguments:
# #      impulse  : name of the shocking variable
# #      response : name of the responding variable
# #      n.ahead  : number of horizons to compute
# #      ci       : confidence level for bootstrap bands (set to NULL to skip)
# #      nboot    : number of bootstrap replications (only used if ci != NULL)
# ```

# %%
irf_impulse  <- "E"     # variable being shocked (must be in endog_vars)
irf_response <- "ipc"   # variable whose response we measure (must be in endog_vars)
irf_horizon  <- 12      # number of quarters ahead
 
# --- Helper: compute IRF for one set of VAR coefficient matrices -------------
# coef_list : list of p matrices (n x n), one per lag, Phi_1 ... Phi_p
# shock_idx : column index of the shocked variable (1-based)
# n_ahead   : number of horizons
# Returns a matrix (n_ahead+1) x n  of impulse responses (row 1 = impact period)
 
compute_irf <- function(coef_list, n_vars, shock_idx, n_ahead) {
  p       <- length(coef_list)
  horizon <- n_ahead + 1
  irf_mat <- matrix(0, nrow = horizon, ncol = n_vars)
 
  # Impact period: unit shock to variable shock_idx
  irf_mat[1, shock_idx] <- 1
 
  # Iterate VAR recursion: y_t = Phi_1 y_{t-1} + ... + Phi_p y_{t-p}
  for (h in 2:horizon) {
    for (lag in 1:min(p, h - 1)) {
      irf_mat[h, ] <- irf_mat[h, ] + irf_mat[h - lag, ] %*% t(coef_list[[lag]])
    }
  }
  irf_mat
}

# %%
# --- Inspect coef() structure first -----------------------------------------
all_coefs  <- coef(fit.VLSTAR)
cat("\n>>> coef() structure diagnostic:\n")
cat("Number of equations:", length(all_coefs), "\n")
cat("First equation column names:\n")
print(names(all_coefs[[1]]))
cat("First equation head:\n")
print(head(all_coefs[[1]]))
cat("\n")
# Out:
# >>> coef() structure diagnostic:
# Number of equations: 0
# First equation column names:
# NULL
# First equation head:
# NULL

# %%
# --- Extract coefficient matrices from the VLSTAR fit ---------------------

all_coefs  <- coef(fit.VLSTAR)
n_vars     <- ncol(y)
var_names  <- colnames(y)
p          <- regression_var_lag
 
# Build coefficient arrays: regime_coefs[[regime]][[lag]] is an (n x n) matrix
# Rows = responding equations, Cols = lagged variables
regime_coefs <- list()
 
for (regime in 0:1) {
  regime_coefs[[regime + 1]] <- vector("list", p)
  for (lag in 1:p) {
    mat <- matrix(0, nrow = n_vars, ncol = n_vars)
    for (eq in seq_len(n_vars)) {
      eq_coefs  <- all_coefs[[eq]]
      # Column names follow pattern "Phi0_lag1", "Phi1_lag1", etc.
      col_names <- paste0("Phi", regime, "_lag", lag)
      # If regime == 1, coefficients are *incremental*; add regime 0 base
      if (regime == 1) {
        base_cols  <- paste0("Phi0_lag", lag)
        base_vals  <- as.numeric(eq_coefs[, base_cols, drop = TRUE])
        incr_vals  <- as.numeric(eq_coefs[, col_names, drop = TRUE])
        mat[eq, ]  <- base_vals + incr_vals
      } else {
        mat[eq, ]  <- as.numeric(eq_coefs[, col_names, drop = TRUE])
      }
    }
    regime_coefs[[regime + 1]][[lag]] <- mat
  }
}
# Out:
# Error in mat[eq, ] <- as.numeric(eq_coefs[, col_names, drop = TRUE]): replacement has length zero
# Traceback:

# %% [markdown]
# #### Cumulate IRFs

# %%
impulse_idx  <- which(var_names == irf_impulse)
response_idx <- which(var_names == irf_response)
 
if (length(impulse_idx) == 0)
  stop("irf_impulse variable '", irf_impulse, "' not found in endog_vars.")
if (length(response_idx) == 0)
  stop("irf_response variable '", irf_response, "' not found in endog_vars.")
 
regime_labels <- c("Regime 0 (low ipc)", "Regime 1 (high ipc)")
cirf_results  <- list()
 
cat("\n>>> Cumulative IRFs:", irf_impulse, "->", irf_response, "\n\n")
 
for (r in 1:2) {
  irf_mat  <- compute_irf(regime_coefs[[r]], n_vars, impulse_idx, irf_horizon)
  irf_vec  <- irf_mat[, response_idx]          # period-by-period IRF
  cirf_vec <- cumsum(irf_vec)                  # cumulative IRF
 
  cirf_results[[r]] <- list(irf = irf_vec, cirf = cirf_vec)
 
  df_out <- data.frame(
    horizon = 0:irf_horizon,
    IRF     = round(irf_vec,  6),
    CIRF    = round(cirf_vec, 6)
  )
  cat(regime_labels[r], "\n")
  print(df_out, row.names = FALSE)
  cat("\n")
}
# Out:
# >>> Cumulative IRFs: E -> ipc
# Error in t.default(coef_list[[lag]]): argument is not a matrix
# Traceback:
#
# 1. t(coef_list[[lag]])
# 2. t.default(coef_list[[lag]])
# 3. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "argument is not a matrix", base::quote(t.default(coef_list[[lag]])))

# %% [markdown]
# # Plot

# %%
par(mfrow = c(2, 2), mar = c(4, 4, 3, 1))
horizons <- 0:irf_horizon
 
for (r in 1:2) {
  # Period-by-period IRF
  plot(horizons, cirf_results[[r]]$irf,
       type = "l", lwd = 2, col = "steelblue",
       xlab = "Horizon (quarters)", ylab = "Response",
       main = paste0("IRF: ", irf_impulse, " -> ", irf_response,
                     "\n", regime_labels[r]))
  abline(h = 0, lty = 2, col = "grey60")
 
  # Cumulative IRF
  plot(horizons, cirf_results[[r]]$cirf,
       type = "l", lwd = 2, col = "darkred",
       xlab = "Horizon (quarters)", ylab = "Cumulative response",
       main = paste0("CIRF: ", irf_impulse, " -> ", irf_response,
                     "\n", regime_labels[r]))
  abline(h = 0, lty = 2, col = "grey60")
}
 
par(mfrow = c(1, 1))
# Out:
# Error in cirf_results[[r]]: subscript out of bounds
# Traceback:
#
# 1. plot.default(horizons, cirf_results[[r]]$irf, type = "l", lwd = 2,
#  .     col = "steelblue", xlab = "Horizon (quarters)", ylab = "Response",
#  .     main = paste0("IRF: ", irf_impulse, " -> ", irf_response,
#  .         "\n", regime_labels[r]))
# 2. xy.coords(x, y, xlabel, ylabel, log)
